# %%
def chatbot_response(user_input):
    user_input = user_input.lower()

    if any(greeting in user_input for greeting in ['hi', 'hello', 'hey']):
        return "Hello! How can I assist you today?"

    elif any(question in user_input for question in ['how are you', 'how are you doing']):
        return "I'm just a chatbot, but I'm here to help you!"

    elif any(bye_word in user_input for bye_word in ['bye', 'goodbye']):
        return "Goodbye! Have a great day!"

    elif any(name_word in user_input for name_word in ['name', 'who are you']):
        return "I am a simple rule-based chatbot."

    elif any(joke_word in user_input for joke_word in ['joke', 'tell me a joke']):
        return "Why don't scientists trust atoms? Because they make up everything!"

    elif 'weather' in user_input:
        return "I'm sorry, I don't have access to real-time data. You can check a weather website for that."

    elif any(age_word in user_input for age_word in ['age', 'old are you']):
        return "I'm just a chatbot, so I don't have an age!"

    elif 'how to' in user_input:
        return "I can't provide detailed instructions, but I can offer general advice. What do you need help with?"

    elif any(love_word in user_input for love_word in ['love', 'like']):
        return "It's great that you have positive feelings!"

    elif 'time' in user_input:
        return "I don't have real-time access to the current time. You can check your device's clock."

    elif 'help' in user_input:
        return "Sure, I'd be happy to help. What do you need assistance with?"

    elif 'thank you' in user_input:
        return "You're welcome! If you have more questions, feel free to ask."

    elif any(learn_word in user_input for learn_word in ['learn', 'study']):
        return "Learning is a wonderful way to grow. What subject or skill are you interested in?"

    elif any(good_word in user_input for good_word in ['good', 'well']):
        return "I'm glad to hear that you're doing well!"

    elif any(feeling_word in user_input for feeling_word in ['feeling', 'feel']):
        return "Feelings can be complex. How are you feeling right now?"

    elif 'news' in user_input:
        return "I don't have access to real-time news updates. You can check a news website for the latest information."

    elif any(plan_word in user_input for plan_word in ['plan', 'future']):
        return "It's important to plan for the future. What are your goals?"

    elif 'movie' in user_input:
        return "I can't recommend movies, but there are many great ones out there. What genre do you enjoy?"

    elif 'music' in user_input:
        return "Music is a wonderful way to express emotions. What's your favorite genre?"

    elif 'food' in user_input:
        return "Food is a universal pleasure. What's your favorite cuisine?"

    elif 'travel' in user_input:
        return "Traveling broadens the mind. Do you have a dream travel destination?"

    elif 'hobby' in user_input:
        return "Hobbies can be a great way to relax. What's your favorite hobby?"

    elif any(book_word in user_input for book_word in ['book', 'read']):
        return "Reading is a fantastic way to gain knowledge. What's the last book you read?"

    elif 'sports' in user_input:
        return "Sports are a great way to stay active. Do you enjoy playing or watching sports?"

    elif any(emotion_word in user_input for emotion_word in ['happy', 'sad', 'angry']):
        return "Emotions are a natural part of being human. How can I help you cope with your feelings?"

    elif any(language_word in user_input for language_word in ['language', 'learn a language']):
        return "Learning a new language is a valuable skill. Which language are you interested in learning?"

    elif 'nature' in user_input:
        return "Nature is beautiful and soothing. Do you enjoy spending time outdoors?"

    elif any(tech_word in user_input for tech_word in ['technology', 'tech']):
        return "Technology has transformed our lives. Are you excited about any recent technological advancements?"

    elif 'dream' in user_input:
        return "Dreams can be mysterious. Do you often remember your dreams?"

    elif 'exercise' in user_input:
        return "Exercise is important for overall well-being. What's your favorite way to stay active?"

    elif 'money' in user_input:
        return "Money plays a significant role in our lives. How do you manage your finances?"

    elif any(home_word in user_input for home_word in ['home', 'house']):
        return "Home is where the heart is. What's your favorite thing about your home?"

    elif any(truth_word in user_input for truth_word in ['truth', 'lie']):
        return "Honesty is important in relationships. Is there a situation where you struggled with telling the truth?"

    elif 'holiday' in user_input:
        return "Holidays are a time to relax and celebrate. What's your favorite holiday?"

    elif any(dream_word in user_input for dream_word in ['dream', 'ambition']):
        return "Dreams and ambitions drive us forward. What's a goal you're currently working towards?"


    elif any(social_word in user_input for social_word in ['social', 'socialize']):
        return "Social interactions are important for well-being. Do you enjoy spending time with friends and family?"

    elif 'technology' in user_input:
        return "Technology is constantly evolving. Are you excited about any upcoming technological innovations?"

    elif 'mindfulness' in user_input:
        return "Mindfulness can improve mental well-being. Have you tried any mindfulness techniques?"

    elif 'career' in user_input:
        return "A career is a significant part of life. What's your dream job?"

    elif any(future_word in user_input for future_word in ['future', 'foresee']):
        return "The future is uncertain. What are your hopes for the future?"

    elif 'pets' in user_input:
        return "Pets bring joy to our lives. Do you have any favorite pets?"

    elif any(nature_word in user_input for nature_word in ['nature', 'outdoors']):
        return "Nature is refreshing. Do you enjoy spending time in natural environments?"

    elif any(home_word in user_input for home_word in ['home', 'house']):
        return "Home is where we find comfort. What's your favorite thing about your living space?"

    elif any(truth_word in user_input for truth_word in ['truth', 'lie']):
        return "Honesty is important. Have you ever been in a situation where telling the truth was challenging?"

    elif 'holiday' in user_input:
        return "Holidays are a time to unwind. What's your preferred holiday destination?"

    elif any(dream_word in user_input for dream_word in ['dream', 'ambition']):
        return "Dreams drive us forward. What's a goal you're currently striving for?"

    elif any(social_word in user_input for social_word in ['social', 'socialize']):
        return "Social interactions are valuable. Do you enjoy spending time with friends and family?"

    elif any(future_word in user_input for future_word in ['future', 'foresee']):
        return "The future is uncertain. What aspirations do you have for the future?"

    else:
        return "I'm sorry, I don't understand that."

# Main loop
print("Chatbot: Hello! How can I assist you today?")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("Chatbot: Goodbye! Have a great day!")
        break
    response = chatbot_response(user_input)
    print("Chatbot:", response)
# Out:
# Chatbot: Hello! How can I assist you today?
# You: hi
# Chatbot: Hello! How can I assist you today?
# You: how are you
# Chatbot: I'm just a chatbot, but I'm here to help you!
# You: who are you
# Chatbot: I am a simple rule-based chatbot.
# You: tell me a joke
# Chatbot: Why don't scientists trust atoms? Because they make up everything!
# You: how old are you
# Chatbot: I'm just a chatbot, so I don't have an age!
# You: how to feel better?
# Chatbot: I can't provide detailed instructions, but I can offer general advice. What do you need help with?
# You: tell me what time it is
# Chatbot: I don't have real-time access to the current time. You can check your device's clock.
# You: what do you know about feelings?
# Chatbot: Feelings can be complex. How are you feeling right now?
# You: help me
# Chatbot: Sure, I'd be happy to help. What do you need assistance with?
# You: suggest a movie
# ...
